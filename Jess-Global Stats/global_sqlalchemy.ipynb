# %%
# Pandas
import pandas as pd
from sqlite3 import connect

# SQL Alchemy
from sqlalchemy import create_engine
import psycopg2

# %%
# declare the connection string specifying
# the host name database name use name
# and password
conn_string = "host='localhost' dbname='world_vaccination_data'\
user='postgres' password='addycole#422'"
 
# use connect function to establish the connection
conn = psycopg2.connect(conn_string)

# %%
# Query All Records in the the Database
data = pd.read_sql('select * from global_vaccine', conn)
# Out:
# /var/folders/5p/wfb670bs10j8zx7mhl7x9vz00000gn/T/ipykernel_92323/3798178508.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql('select * from global_vaccine', conn)

# %%
# Preview the Data
data.head()
# Out:
#           Country           Capital  Latitude  Longitude First_Vaccine_Date  \
# 0     Afghanistan             Kabul     34.28      69.11         2021-02-22
# 1         Albania            Tirane     41.18      19.49         2021-01-13
# 2         Algeria           Algiers     36.42       3.08         2021-01-30
# 3  American Samoa         Pago Pago    -14.16    -170.43         2020-12-21
# 4         Andorra  Andorra la Vella     42.31       1.32         2021-01-20
#
#    Total_Vaccinations  Persons_Vaccinated_with_1_Dose  \
# 0          16586584.0                      14526772.0
# 1           3070468.0                       1347054.0
# 2          15267442.0                       7840131.0
# 3            111316.0                         46201.0
# 4            156957.0                         57904.0
#
#    Persons_Fully_Vaccinated  Nunber_of_Vaccine_Types_Used  \
# 0                13815117.0                          11.0
# 1                 1276432.0                           5.0
# ...
